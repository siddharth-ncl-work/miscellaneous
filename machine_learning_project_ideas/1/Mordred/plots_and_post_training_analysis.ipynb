# %%
LIBRARY='mordred'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from tqdm import tqdm
import pickle
from IPython.display import clear_output

# %%
SMALL_SIZE = 20
MEDIUM_SIZE = 25
BIGGER_SIZE = 30

mpl.rcParams['axes.grid'] = True
mpl.rcParams['figure.figsize']=(16,9)
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
def getDataFromFile(file_name):
    try:
        with open(file_name, 'rb') as file:
            print('File Found')
            return pickle.load(file)
    except FileNotFoundError:
        print('File Not Found, performe the whole process...')
        return None

# %% [markdown]
# # Optimized Models Vs. Error (Stacked Histogram wrt Feature Type)

# %%
# MODEL_OPT_DF_2d+3d+fp_rdkit.pkl
file_name=f'MODEL_PERFORMANCE_DF_2d+3d+fp_{LIBRARY}.pkl'
df1=getDataFromFile(file_name)
file_name=f'MODEL_PERFORMANCE_DF_2d+3d_{LIBRARY}.pkl'
df2=getDataFromFile(file_name)
file_name=f'MODEL_PERFORMANCE_DF_2d_{LIBRARY}.pkl'
df3=getDataFromFile(file_name)
file_name=f'MODEL_PERFORMANCE_DF_3d_{LIBRARY}.pkl'
df4=getDataFromFile(file_name)
df=pd.concat([df1,df2,df3,df4])
df
# Out:
# File Found
# File Found
# File Found
# File Found
#           feat_set_x             model_name  \
# 0   2d+3d+fp_mordred             linear_reg
# 1   2d+3d+fp_mordred                  ridge
# 2   2d+3d+fp_mordred                  lasso
# 3   2d+3d+fp_mordred            elastic_net
# 4   2d+3d+fp_mordred             lasso_lars
# ..               ...                    ...
# 15        3d_mordred          random_forest
# 16        3d_mordred              ada_boost
# 17        3d_mordred  gradient_boosting_reg
# 18        3d_mordred         neural_network
# 19        3d_mordred                knn_reg
#
#                                             opt_model  \
# 0                     LinearRegression(positive=True)
# 1                      Ridge(alpha=0.5, max_iter=500)
# 2      Lasso(alpha=0.01, max_iter=100, positive=True)
# 3   ElasticNet(alpha=0.5, l1_ratio=0.2, max_iter=5...
# 4   LassoLars(alpha=0.01, max_iter=100, positive=T...
# ..                                                ...
# 15  (DecisionTreeRegressor(max_features='auto', ra...
# 16  (DecisionTreeRegressor(max_depth=3, random_sta...
# 17  ([DecisionTreeRegressor(criterion='friedman_ms...
# 18  MLPRegressor(early_stopping=True, hidden_layer...
# 19   KNeighborsRegressor(leaf_size=40, n_neighbors=1)
#
#                                            opt_params        feat_set_y  \
# 0   {'fit_intercept': True, 'normalize': False, 'p...  2d+3d+fp_mordred
# 1   {'alpha': 0.5, 'max_iter': 500, 'solver': 'aut...  2d+3d+fp_mordred
# 2   {'alpha': 0.01, 'max_iter': 100, 'positive': T...  2d+3d+fp_mordred
# 3   {'alpha': 0.5, 'l1_ratio': 0.2, 'max_iter': 50...  2d+3d+fp_mordred
# 4   {'alpha': 0.01, 'jitter': None, 'max_iter': 10...  2d+3d+fp_mordred
# ..                                                ...               ...
# 15  {'bootstrap': True, 'n_estimators': 50, 'oob_s...        3d_mordred
# 16  {'learning_rate': 1, 'loss': 'square', 'n_esti...        3d_mordred
# 17  {'max_depth': 2, 'n_estimators': 250, 'tol': 0...        3d_mordred
# 18  {'activation': 'relu', 'early_stopping': True,...        3d_mordred
# 19  {'algorithm': 'auto', 'leaf_size': 40, 'n_neig...        3d_mordred
#
#     cv_mean_test_r2  cv_mean_test_mse  cv_mean_test_mae          feat_set  \
# 0          0.930290          0.030873          0.102717  2d+3d+fp_mordred
# 1          0.955881          0.019783          0.083853  2d+3d+fp_mordred
# 2          0.924848          0.030284          0.124689  2d+3d+fp_mordred
# 3          0.795277          0.085651          0.241691  2d+3d+fp_mordred
# 4          0.820624          0.073389          0.216896  2d+3d+fp_mordred
# ..              ...               ...               ...               ...
# 15         0.767778          0.100733          0.151608        3d_mordred
# 16         0.846284          0.064669          0.153732        3d_mordred
# 17         0.856918          0.067425          0.130135        3d_mordred
# 18         0.845496          0.065221          0.108706        3d_mordred
# 19         0.865774          0.074805          0.098135        3d_mordred
#
#      test_r2  test_mse  test_mae
# 0   0.909180  0.038496  0.120980
# 1   0.885091  0.048706  0.122869
# 2   0.861436  0.058733  0.148138
# 3   0.773293  0.096094  0.253799
# 4   0.724887  0.116612  0.240223
# ..       ...       ...       ...
# 15  0.856282  0.060918  0.148923
# 16  0.670619  0.139614  0.214833
# 17  0.897479  0.043455  0.126236
# 18  0.912319  0.037165  0.103573
# 19  0.379170  0.263150  0.222500
#
# [80 rows x 12 columns]

# %%
# plt.barh(df['model_name'],df['test_mse'])
df=df.sort_values(by='test_mse')
plt.figure(figsize=(9,16))
sns.barplot(x='test_mse', y='model_name',  data=df, hue='feat_set')
plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# # Best Model Error Vs. Num Features

# %%
# BEST_MODEL_VS_NUM_FETUREs_2d+3d+fp_rdkit.pkl
file_name=f'BEST_MODEL_VS_NUM_FETURES_2d+3d+fp_{LIBRARY}.pkl'
df=getDataFromFile(file_name)
df=df.set_index('num_feat')
df
# Out:
# File Found
#                feat_set model_name   test_r2  test_mse  test_mae
# num_feat
# 1            2d_mordred      huber  0.526797  0.200576  0.360341
# 2            2d_mordred      huber  0.518669  0.204021  0.365062
# 3            2d_mordred      huber  0.521166  0.202962  0.364238
# 4            2d_mordred      huber  0.563148  0.185167  0.276802
# 5            2d_mordred      huber  0.669547  0.140068  0.250329
# 6            2d_mordred      huber  0.669546  0.140069  0.250329
# 7            2d_mordred      huber  0.669718  0.139996  0.250293
# 8            2d_mordred      huber  0.716687  0.120087  0.245015
# 9            2d_mordred      huber  0.739540  0.110400  0.240441
# 10           2d_mordred      huber  0.889124  0.046997  0.156183
# 11           2d_mordred      huber  0.890824  0.046276  0.152330
# 12           2d_mordred      huber  0.718962  0.119123  0.199070
# 13           2d_mordred      huber  0.758781  0.102245  0.187119
# 14           2d_mordred      huber  0.747472  0.107038  0.187779
# 15           2d_mordred      huber  0.751061  0.105517  0.185191
# 16        3d+2d_mordred      huber  0.599212  0.169881  0.193794
# 17        3d+2d_mordred      huber  0.783905  0.091596  0.165909
# 18        3d+2d_mordred      huber  0.805409  0.082481  0.162739
# 19        3d+2d_mordred      huber  0.954417  0.019321  0.101202
# 20        3d+2d_mordred      huber  0.945034  0.023298  0.106451
# 21        3d+2d_mordred      huber  0.954434  0.019314  0.103584
# 22        3d+2d_mordred      huber  0.955063  0.019047  0.101586
# 23        3d+2d_mordred      huber  0.947814  0.022120  0.103118
# 24        3d+2d_mordred      huber  0.926809  0.031023  0.107353
# 25        3d+2d_mordred      huber  0.943457  0.023967  0.099322
# 26        3d+2d_mordred      huber  0.942454  0.024392  0.099962
# 27        3d+2d_mordred      huber  0.944625  0.023472  0.098625
# 28        3d+2d_mordred      huber  0.944376  0.023577  0.098769
# 29        3d+2d_mordred      huber  0.941723  0.024702  0.100260

# %%
sns.lineplot(data=df[['test_r2','test_mse','test_mae']])
plt.title(df['model_name'].values[0])
plt.xlim(0,100)

# left, bottom, width, height = [0.25, 0.6, 0.2, 0.2]
# ax2 = fig.add_axes([left, bottom, width, height])
# Out:
# (0.0, 100.0)

# %% [markdown]
# # Feature Importance Plots

# %%
# FETURE_IMPORTANCE_DF_2d+3d+fp_{LIBRARY}.pkl
file_name=f'FETURE_IMPORTANCE_DF_2d+3d+fp_{LIBRARY}.pkl'
df=getDataFromFile(file_name)
df
# Out:
# File Found
#               feat_name  random_forest_score  ada_boost_score  \
# 0        ABC_2d_mordred             0.004468         0.008005
# 1      ABCGG_2d_mordred             0.003870         0.006296
# 2      nAcid_2d_mordred             0.000047         0.000968
# 3    SpAbs_A_2d_mordred             0.020131         0.011156
# 4    SpMax_A_2d_mordred             0.003342         0.004870
# 5   SpDiam_A_2d_mordred             0.003993         0.010744
# 6     SpAD_A_2d_mordred             0.027117         0.016402
# 7    SpMAD_A_2d_mordred             0.001312         0.000155
# 8    LogEE_A_2d_mordred             0.004550         0.002412
# 9      VE1_A_2d_mordred             0.003808         0.013825
# 10     VE2_A_2d_mordred             0.020719         0.027531
# 11     VE3_A_2d_mordred             0.002887         0.000913
# 12     VR1_A_2d_mordred             0.005933         0.113661
# 13     VR2_A_2d_mordred             0.789292         0.612435
# 14     VR3_A_2d_mordred             0.003727         0.002412
# 15     PNSA1_3d_mordred             0.018415         0.018768
# 16     PNSA2_3d_mordred             0.007912         0.015352
# 17     PNSA3_3d_mordred             0.014219         0.018622
# 18     PNSA4_3d_mordred             0.003292         0.005425
# 19     PNSA5_3d_mordred             0.012642         0.015526
# 20     PPSA1_3d_mordred             0.000972         0.005937
# 21     PPSA2_3d_mordred             0.001494         0.002264
# 22     PPSA3_3d_mordred             0.008965         0.041236
# 23     PPSA4_3d_mordred             0.000642         0.000978
# 24     PPSA5_3d_mordred             0.000918         0.000000
# 25     DPSA1_3d_mordred             0.016728         0.012942
# 26     DPSA2_3d_mordred             0.000864         0.001576
# 27     DPSA3_3d_mordred             0.005995         0.017126
# 28     DPSA4_3d_mordred             0.001897         0.000013
# 29     DPSA5_3d_mordred             0.009848         0.012449
#
#     gradient_boosting_reg_score  kbest_selector_score  \
# 0                      0.000331              1.286622
# 1                      0.003197              1.237426
# 2                      0.000235              0.000000
# 3                      0.032976              1.248787
# 4                      0.005609              0.644148
# 5                      0.003580              0.649504
# 6                      0.018684              1.253025
# 7                      0.000039              1.004077
# 8                      0.000035              1.132090
# 9                      0.000350              1.211943
# 10                     0.010373              1.193007
# 11                     0.004671              1.146879
# 12                     0.001329              1.178218
# 13                     0.804863              1.334130
# 14                     0.001292              1.165469
# 15                     0.029228              0.912715
# 16                     0.002996              0.857240
# 17                     0.023267              1.303564
# 18                     0.002143              0.977683
# 19                     0.000709              1.243213
# 20                     0.000788              0.768843
# 21                     0.000826              0.904751
# 22                     0.004407              1.173749
# 23                     0.000130              0.947540
# 24                     0.000238              0.915083
# 25                     0.023039              0.892514
# 26                     0.000625              1.248560
# 27                     0.000881              1.247176
# 28                     0.000017              1.231120
# 29                     0.023144              1.081145
#
#     mean_permutation_imp_score
# 0                     0.637430
# 1                     0.064180
# 2                     0.000318
# 3                     0.117329
# 4                     0.002633
# 5                     0.002084
# 6                     0.114528
# 7                     0.005344
# 8                     6.505143
# 9                     0.106583
# 10                    0.138207
# 11                    4.523221
# 12                    0.277411
# 13                    0.497641
# 14                    0.641723
# 15                    0.026764
# 16                    0.027667
# 17                    0.054393
# 18                    0.012308
# 19                    0.043225
# 20                    0.063970
# 21                    0.177440
# 22                    0.048817
# 23                    0.139777
# 24                    0.030910
# 25                    0.006648
# 26                    0.030538
# 27                    0.014807
# 28                    0.084712
# 29                    0.014942

# %%
ntop=20
df=df.sort_values(by='random_forest_score',ascending=False)
plt.figure(figsize=(9,16))
sns.barplot(x='random_forest_score',y='feat_name',data=df[:ntop])
# Out:
# <AxesSubplot:xlabel='random_forest_score', ylabel='feat_name'>

# %% [markdown]
# # Model Performance on Top n=20 Features

# %%
# TOP_FEAT_MODEL_PERFORMANCE_DATA_DF_rdkit.pkl
file_name=f'TOP_5_FEAT_MODEL_PERFORMANCE_DF_{LIBRARY}.pkl'
df1=getDataFromFile(file_name)
file_name=f'TOP_10_FEAT_MODEL_PERFORMANCE_DF_{LIBRARY}.pkl'
df2=getDataFromFile(file_name)
file_name=f'TOP_15_FEAT_MODEL_PERFORMANCE_DF_{LIBRARY}.pkl'
df3=getDataFromFile(file_name)
file_name=f'TOP_20_FEAT_MODEL_PERFORMANCE_DF_{LIBRARY}.pkl'
df3=getDataFromFile(file_name)
df=pd.concat([df1,df2,df3,df4])
df
# Out:
# File Found
# File Found
# File Found
# File Found
#              feat_set_x             model_name  \
# 0   top_20_feat_mordred             linear_reg
# 1   top_20_feat_mordred                  ridge
# 2   top_20_feat_mordred                  lasso
# 3   top_20_feat_mordred            elastic_net
# 4   top_20_feat_mordred             lasso_lars
# ..                  ...                    ...
# 15           3d_mordred          random_forest
# 16           3d_mordred              ada_boost
# 17           3d_mordred  gradient_boosting_reg
# 18           3d_mordred         neural_network
# 19           3d_mordred                knn_reg
#
#                                             opt_model  \
# 0                     LinearRegression(positive=True)
# 1   Ridge(alpha=0.5, max_iter=500, solver='lsqr', ...
# 2      Lasso(alpha=0.01, max_iter=100, positive=True)
# 3   ElasticNet(alpha=0.5, l1_ratio=0.2, max_iter=5...
# 4   LassoLars(alpha=0.01, max_iter=100, positive=T...
# ..                                                ...
# 15  (DecisionTreeRegressor(max_features='auto', ra...
# 16  (DecisionTreeRegressor(max_depth=3, random_sta...
# 17  ([DecisionTreeRegressor(criterion='friedman_ms...
# 18  MLPRegressor(early_stopping=True, hidden_layer...
# 19   KNeighborsRegressor(leaf_size=40, n_neighbors=1)
#
#                                            opt_params           feat_set_y  \
# 0   {'fit_intercept': True, 'normalize': False, 'p...  top_20_feat_mordred
# 1   {'alpha': 0.5, 'max_iter': 500, 'solver': 'lsq...  top_20_feat_mordred
# 2   {'alpha': 0.01, 'max_iter': 100, 'positive': T...  top_20_feat_mordred
# 3   {'alpha': 0.5, 'l1_ratio': 0.2, 'max_iter': 50...  top_20_feat_mordred
# 4   {'alpha': 0.01, 'jitter': None, 'max_iter': 10...  top_20_feat_mordred
# ..                                                ...                  ...
# 15  {'bootstrap': True, 'n_estimators': 50, 'oob_s...           3d_mordred
# 16  {'learning_rate': 1, 'loss': 'square', 'n_esti...           3d_mordred
# 17  {'max_depth': 2, 'n_estimators': 250, 'tol': 0...           3d_mordred
# 18  {'activation': 'relu', 'early_stopping': True,...           3d_mordred
# 19  {'algorithm': 'auto', 'leaf_size': 40, 'n_neig...           3d_mordred
#
#     cv_mean_test_r2  cv_mean_test_mse  cv_mean_test_mae    feat_set   test_r2  \
# 0          0.930290          0.030873          0.102717  3d_mordred  0.909180
# 1          0.955978          0.019774          0.083541  3d_mordred  0.885300
# 2          0.924848          0.030284          0.124689  3d_mordred  0.861436
# 3          0.795277          0.085651          0.241691  3d_mordred  0.773293
# 4          0.820624          0.073389          0.216896  3d_mordred  0.724887
# ..              ...               ...               ...         ...       ...
# 15         0.767778          0.100733          0.151608  3d_mordred  0.856282
# 16         0.846284          0.064669          0.153732  3d_mordred  0.670619
# 17         0.856918          0.067425          0.130135  3d_mordred  0.897479
# 18         0.845496          0.065221          0.108706  3d_mordred  0.912319
# 19         0.865774          0.074805          0.098135  3d_mordred  0.379170
#
#     test_mse  test_mae
# 0   0.038496  0.120980
# 1   0.048618  0.122717
# 2   0.058733  0.148138
# 3   0.096094  0.253799
# 4   0.116612  0.240223
# ..       ...       ...
# 15  0.060918  0.148923
# 16  0.139614  0.214833
# 17  0.043455  0.126236
# 18  0.037165  0.103573
# 19  0.263150  0.222500
#
# [80 rows x 12 columns]

# %%
df=df.sort_values(by='test_mse')
sns.barplot(x='test_mse',y='model_name',data=df,hue='feat_set_x')
# Out:
# <AxesSubplot:xlabel='test_mse', ylabel='model_name'>

# %% [markdown]
# # Model Error per Class of Compound

# %%
# BEST_MODEL_ERROR_PER_COMPOUND_TRAIN_rdkit.pkl
file_name=f'BEST_MODEL_MEAN_ERROR_PER_COMPOUND_TRAIN_{LIBRARY}.pkl'
df1=getDataFromFile(file_name)
df1['label']='train'
file_name=f'BEST_MODEL_MEAN_ERROR_PER_COMPOUND_TEST_{LIBRARY}.pkl'
df2=getDataFromFile(file_name)
df2['label']='test'
df=pd.concat([df1,df2])
df
# Out:
# File Found
# File Found
#            true_y    pred_y  abs_error  %abs_error model_name  \
# FG_name
# F       -1.680000 -1.678589   0.001411    0.083977      huber
# 2CH3N   -1.915000 -1.911934   0.003066    0.162372      huber
# CH3     -1.790000 -1.795954   0.010397    0.580845      huber
# CONH2   -1.575000 -1.553578   0.021422    1.401987      huber
# COCH3   -1.550000 -1.521529   0.028471    1.836841      huber
# NH2     -2.136970 -2.136154   0.036956    1.732311      huber
# OH      -1.806000 -1.807439   0.039257    2.174953      huber
# NO2     -0.679474 -0.682274   0.040843    5.627520      huber
# COOH    -1.415000 -1.415001   0.041047    2.920126      huber
# CH2=CH  -1.720000 -1.678595   0.041405    2.407289      huber
# CN      -0.678889 -0.694419   0.045001    8.254938      huber
# -       -1.740000 -1.798481   0.058481    3.360988      huber
# CF3     -1.540000 -1.544496   0.077538    5.033237      huber
# CHO     -1.505000 -1.400776   0.104224    6.922486      huber
# S(CH3)2 -1.740000 -1.627561   0.112439    6.461986      huber
# SH      -1.660000 -1.814973   0.154973    9.335751      huber
# Cl      -1.630000 -1.789780   0.159780    9.802431      huber
# P(CH3)2 -1.740000 -1.550912   0.189088   10.867149      huber
# OCH3    -1.860000 -1.437360   0.422640   22.722585      huber
# F       -1.630000 -1.636642   0.006642    0.407470      huber
# NH2     -2.092941 -2.081531   0.038835    1.769316      huber
# CN      -0.748462 -0.763299   0.041476   39.069290      huber
# P(CH3)2 -1.750000 -1.707422   0.042578    2.433036      huber
# NO2     -0.560000 -0.524279   0.082427   21.625077      huber
# CH2=CH  -1.730000 -1.635585   0.094415    5.457525      huber
# S(CH3)2 -1.770000 -1.672221   0.097779    5.524231      huber
# Cl      -1.610000 -1.713354   0.103354    6.419497      huber
# OH      -1.835000 -1.762727   0.132920    7.376875      huber
# COCH3   -1.580000 -1.434879   0.145121    9.184885      huber
# SH      -1.720000 -1.894988   0.174988   10.173710      huber
# C6H5    -1.745000 -1.396191   0.348809   19.972136      huber
# OCH3    -1.750000 -1.394138   0.355862   20.334998      huber
# COOCH3  -1.595000 -1.077000   0.518000   32.457016      huber
#
#                  feat_set  label
# FG_name
# F        2d+3d+fp_mordred  train
# 2CH3N    2d+3d+fp_mordred  train
# CH3      2d+3d+fp_mordred  train
# CONH2    2d+3d+fp_mordred  train
# COCH3    2d+3d+fp_mordred  train
# NH2      2d+3d+fp_mordred  train
# OH       2d+3d+fp_mordred  train
# NO2      2d+3d+fp_mordred  train
# COOH     2d+3d+fp_mordred  train
# CH2=CH   2d+3d+fp_mordred  train
# CN       2d+3d+fp_mordred  train
# -        2d+3d+fp_mordred  train
# CF3      2d+3d+fp_mordred  train
# CHO      2d+3d+fp_mordred  train
# S(CH3)2  2d+3d+fp_mordred  train
# SH       2d+3d+fp_mordred  train
# Cl       2d+3d+fp_mordred  train
# P(CH3)2  2d+3d+fp_mordred  train
# OCH3     2d+3d+fp_mordred  train
# F        2d+3d+fp_mordred   test
# NH2      2d+3d+fp_mordred   test
# CN       2d+3d+fp_mordred   test
# P(CH3)2  2d+3d+fp_mordred   test
# NO2      2d+3d+fp_mordred   test
# CH2=CH   2d+3d+fp_mordred   test
# S(CH3)2  2d+3d+fp_mordred   test
# Cl       2d+3d+fp_mordred   test
# OH       2d+3d+fp_mordred   test
# COCH3    2d+3d+fp_mordred   test
# SH       2d+3d+fp_mordred   test
# C6H5     2d+3d+fp_mordred   test
# OCH3     2d+3d+fp_mordred   test
# COOCH3   2d+3d+fp_mordred   test

# %%
df=df.reset_index()
plt.figure(figsize=(9,16))
sns.barplot(y='FG_name',x='%abs_error',data=df, hue='label')
# Out:
# <AxesSubplot:xlabel='%abs_error', ylabel='FG_name'>
